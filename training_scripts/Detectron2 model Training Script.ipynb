# %%
# %%capture
# !python -m pip install pyyaml==5.1
import sys, os, distutils.core
# Note: This is a faster way to install detectron2 in Colab, but it does not include all functionalities.
# See https://detectron2.readthedocs.io/tutorials/install.html for full installation instructions
# !git clone 'https://github.com/facebookresearch/detectron2'
# dist = distutils.core.run_setup("./detectron2/setup.py")
# !python -m pip install {' '.join([f"'{x}'" for x in dist.install_requires])}
# sys.path.insert(0, os.path.abspath('./detectron2'))

# Properly install detectron2. (Please do not install twice in both ways)
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'

# %%
import torch, detectron2
# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
print("detectron2:", detectron2.__version__)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# torch:  2.5 ; cuda:  cu121
# detectron2: 0.6

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

import numpy as np
import pandas as pd
import cv2
from google.colab.patches import cv2_imshow

from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %% [markdown]
# ### Register Train and Validation Set

# %% [markdown]
# #### Train

# %%
from detectron2.data.datasets import register_coco_instances
register_coco_instances("my_data_train", {}, "/content/drive/MyDrive/BumpsandPotholes/models/train.json", "/content/drive/MyDrive/BumpsandPotholes/models/train")

# %%
my_data_train_metadata = MetadataCatalog.get("my_data_train")
dataset_dicts = DatasetCatalog.get("my_data_train")
# Out:
# WARNING [01/05 14:47:08 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [01/05 14:47:08 d2.data.datasets.coco]: Loaded 374 images in COCO format from /content/drive/MyDrive/BumpsandPotholes/models/train.json

# %%
my_data_train_metadata
# Out:
# namespace(name='my_data_train',
#           json_file='/content/drive/MyDrive/BumpsandPotholes/models/train.json',
#           image_root='/content/drive/MyDrive/BumpsandPotholes/models/train',
#           evaluator_type='coco',
#           thing_classes=['Pothole', 'RoadPath', 'SpeedBump'],
#           thing_dataset_id_to_contiguous_id={0: 0, 1: 1, 2: 2})

# %%
classes = my_data_train_metadata.thing_classes
classes_df = pd.DataFrame(classes)
classes_df.to_csv('/content/drive/MyDrive/BumpsandPotholes/models/classeslist.csv')

# %%
len(classes)
# Out:
# 3

# %% [markdown]
# #### Validation

# %%
register_coco_instances("my_data_val", {}, "/content/drive/MyDrive/BumpsandPotholes/models/test.json", "/content/drive/MyDrive/BumpsandPotholes/models/test")

# %%
my_data_val_metadata = MetadataCatalog.get("my_data_val")
dataset_dicts = DatasetCatalog.get("my_data_val")
# Out:
# WARNING [01/05 14:48:13 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [01/05 14:48:13 d2.data.datasets.coco]: Loaded 94 images in COCO format from /content/drive/MyDrive/BumpsandPotholes/models/test.json

# %%
my_data_val_metadata
# Out:
# namespace(name='my_data_val',
#           json_file='/content/drive/MyDrive/BumpsandPotholes/models/test.json',
#           image_root='/content/drive/MyDrive/BumpsandPotholes/models/test',
#           evaluator_type='coco',
#           thing_classes=['Pothole', 'RoadPath', 'SpeedBump'],
#           thing_dataset_id_to_contiguous_id={0: 0, 1: 1, 2: 2})

# %% [markdown]
# #### Sample Train Data

# %%
import random
import os
dataset_dicts = DatasetCatalog.get("my_data_train")
for d in random.sample(dataset_dicts, 10):

    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=my_data_train_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    cv2_imshow(vis.get_image()[:, :, ::-1])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #### Data Augmentation

# %%
import detectron2.data.transforms as T

def build_sem_seg_train_aug(cfg):
    augs = [
        T.RandomApply(T.RandomBrightness(0.6, 1.4), prob=0.2),
        T.ResizeShortestEdge( cfg.INPUT.MIN_SIZE_TRAIN, cfg.INPUT.MAX_SIZE_TRAIN, cfg.INPUT.MIN_SIZE_TRAIN_SAMPLING),
        T.RandomApply(T.RandomRotation(sample_style="choice", angle=[90, 180, 270]), prob=0.3),
        T.RandomFlip(prob=0.2, horizontal=False, vertical=True),
        T.RandomFlip(prob=0.2, horizontal=True, vertical=False),
        #T.RandomApply(T.Resize((550,430)), prob=1)
        #T.Resize((550,600)),
        #T.ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'),
        #T.Resize((800,600)),
        #T.RandomFlip(prob=0.5, horizontal=True, vertical=False),
        #T.RandomContrast(0.6, 1.3),
        #T.RandomSaturation(0.8, 1.4),
        #T.RandomRotation(angle=[90, 90]),
        #T.RandomLighting(0.7),
        #T.RandomFlip(prob=0.5, horizontal=False, vertical=True),
        #T.RandomFlip(prob=0.7, horizontal=True, vertical=False)
    ]
    return augs

# %% [markdown]
# #### Calculate Validation Loss

# %%
from detectron2.engine.hooks import HookBase
from detectron2.evaluation import inference_context
from detectron2.utils.logger import log_every_n_seconds
from detectron2.data import DatasetMapper, build_detection_test_loader
import detectron2.utils.comm as comm
import torch
import time
import logging
import datetime

class LossEvalHook(HookBase):
    def __init__(self, eval_period, model, data_loader):
        self._model = model
        self._period = eval_period
        self._data_loader = data_loader

    def _do_loss_eval(self):
        # Copying inference_on_dataset from evaluator.py
        total = len(self._data_loader)
        num_warmup = min(5, total - 1)

        start_time = time.perf_counter()
        total_compute_time = 0
        losses = []
        for idx, inputs in enumerate(self._data_loader):
            if idx == num_warmup:
                start_time = time.perf_counter()
                total_compute_time = 0
            start_compute_time = time.perf_counter()
            if torch.cuda.is_available():
                torch.cuda.synchronize()
            total_compute_time += time.perf_counter() - start_compute_time
            iters_after_start = idx + 1 - num_warmup * int(idx >= num_warmup)
            seconds_per_img = total_compute_time / iters_after_start
            if idx >= num_warmup * 2 or seconds_per_img > 5:
                total_seconds_per_img = (time.perf_counter() - start_time) / iters_after_start
                eta = datetime.timedelta(seconds=int(total_seconds_per_img * (total - idx - 1)))
                log_every_n_seconds(
                    logging.INFO,
                    "Loss on Validation  done {}/{}. {:.4f} s / img. ETA={}".format(
                        idx + 1, total, seconds_per_img, str(eta)
                    ),
                    n=5,
                )
            loss_batch = self._get_loss(inputs)
            losses.append(loss_batch)
        mean_loss = np.mean(losses)
        self.trainer.storage.put_scalar('validation_loss', mean_loss)
        comm.synchronize()

        return losses

    def _get_loss(self, data):
        # How loss is calculated on train_loop
        metrics_dict = self._model(data)
        metrics_dict = {
            k: v.detach().cpu().item() if isinstance(v, torch.Tensor) else float(v)
            for k, v in metrics_dict.items()
        }
        total_losses_reduced = sum(loss for loss in metrics_dict.values())
        return total_losses_reduced

    def after_step(self):
        next_iter = self.trainer.iter + 1
        is_final = next_iter == self.trainer.max_iter
        if is_final or (self._period > 0 and next_iter % self._period == 0):
            self._do_loss_eval()
        self.trainer.storage.put_scalars(timetest=12)

# %% [markdown]
# #### Custom Trainer

# %%
from detectron2.engine import DefaultTrainer
from detectron2.data import build_detection_test_loader, build_detection_train_loader

class MyTrainer(DefaultTrainer):
    @classmethod
    def build_train_loader(cls, cfg):
        mapper = DatasetMapper(cfg, is_train=True, augmentations=build_sem_seg_train_aug(cfg))
        return build_detection_train_loader(cfg, mapper=mapper)

    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = os.path.join(cfg.OUTPUT_DIR, "inference")
        return COCOEvaluator(dataset_name, cfg, True, output_folder)

    def build_hooks(self):
        hooks = super().build_hooks()
        hooks.insert(-1,LossEvalHook(
            cfg.TEST.EVAL_PERIOD,
            self.model,
            build_detection_test_loader(
                self.cfg,
                self.cfg.DATASETS.TEST[0],
                DatasetMapper(self.cfg,True)
            )
        ))
        return hooks

# %% [markdown]
# #### Train Model

# %%
import gc
gc.collect()
# Out:
# 13185

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
import os

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("my_data_train",)
cfg.DATASETS.TEST = ("my_data_val",)   # no metrics implemented for this dataset
cfg.DATALOADER.NUM_WORKERS = 4
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x.yaml") # initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.002
cfg.SOLVER.MAX_ITER = 4200 # Number of iterations
cfg.TEST.EVAL_PERIOD = 4201
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 512
#cfg.MODEL.BACKBONE.FREEZE_AT = 2
cfg.MODEL.ROI_HEADS.NUM_CLASSES = len(classes) # classes

cfg.OUTPUT_DIR = "/content/drive/MyDrive/BumpsandPotholes/models/Detectron2/output/"
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)


trainer = MyTrainer(cfg) #DefaultTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [01/05 14:52:02 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=4, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=12, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [01/05 14:52:02 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [<detectron2.data.transforms.augmentation_impl.RandomApply object at 0x7e049d5ca4d0>, ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), <detectron2.data.transforms.augmentation_impl.RandomApply object at 0x7e049d5ca680>, RandomFlip(prob=0.2, horizontal=False, vertical=True), RandomFlip(prob=0.2)]
# WARNING [01/05 14:52:02 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [01/05 14:52:02 d2.data.datasets.coco]: Loaded 374 images in COCO format from /content/drive/MyDrive/BumpsandPotholes/models/train.json
# [01/05 14:52:02 d2.data.build]: Removed 0 images with no usable annotations. 374 images left.
# [01/05 14:52:02 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |  Pothole   | 263          |  RoadPath  | 362          | SpeedBump  | 221          |
# |            |              |            |              |            |              |
# |   total    | 846          |            |              |            |              |
# [01/05 14:52:02 d2.data.build]: Using training sampler TrainingSampler
# [01/05 14:52:02 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [01/05 14:52:02 d2.data.common]: Serializing 374 elements to byte tensors and concatenating them all ...
# [01/05 14:52:02 d2.data.common]: Serialized dataset takes 0.38 MiB
# [01/05 14:52:02 d2.data.build]: Making batched data loader with batch_size=2
# WARNING [01/05 14:52:02 d2.solver.build]: SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. These values will be ignored.
# [01/05 14:52:02 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# WARNING [01/05 14:52:02 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [01/05 14:52:02 d2.data.datasets.coco]: Loaded 94 images in COCO format from /content/drive/MyDrive/BumpsandPotholes/models/test.json
# [01/05 14:52:02 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |  Pothole   | 43           |  RoadPath  | 95           | SpeedBump  | 68           |
# |            |              |            |              |            |              |
# |   total    | 206          |            |              |            |              |
# [01/05 14:52:02 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [01/05 14:52:02 d2.data.common]: Serializing 94 elements to byte tensors and concatenating them all ...
# [01/05 14:52:02 d2.data.common]: Serialized dataset takes 0.09 MiB
# [01/05 14:52:02 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x/138205316/model_final_a3ec72.pkl ...
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# model_final_a3ec72.pkl: 254MB [00:01, 196MB/s]
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (4, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (4,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (12, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (12,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (3, 256, 1, 1) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (3,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# [01/05 14:52:04 d2.engine.train_loop]: Starting training from iteration 0
# /usr/local/lib/python3.10/dist-packages/fvcore/transforms/transform.py:434: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   tensor = torch.from_numpy(np.ascontiguousarray(img))
# /usr/local/lib/python3.10/dist-packages/fvcore/transforms/transform.py:434: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   tensor = torch.from_numpy(np.ascontiguousarray(img))
# /usr/local/lib/python3.10/dist-packages/fvcore/transforms/transform.py:434: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   tensor = torch.from_numpy(np.ascontiguousarray(img))
# /usr/local/lib/python3.10/dist-packages/fvcore/transforms/transform.py:434: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   tensor = torch.from_numpy(np.ascontiguousarray(img))
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [01/05 14:52:26 d2.utils.events]:  eta: 0:58:35  iter: 19  total_loss: 3.186  loss_cls: 1.386  loss_box_reg: 0.05953  loss_mask: 0.6794  loss_rpn_cls: 0.8085  loss_rpn_loc: 0.2831    time: 0.8308  last_time: 0.7159  data_time: 0.0630  last_data_time: 0.0055   lr: 3.9962e-05  max_mem: 5490M
# [01/05 14:52:45 d2.utils.events]:  eta: 0:54:27  iter: 39  total_loss: 1.808  loss_cls: 0.6512  loss_box_reg: 0.1081  loss_mask: 0.6029  loss_rpn_cls: 0.104  loss_rpn_loc: 0.1748    time: 0.8005  last_time: 0.6330  data_time: 0.0149  last_data_time: 0.0024   lr: 7.9922e-05  max_mem: 5490M
# [01/05 14:53:00 d2.utils.events]:  eta: 0:52:23  iter: 59  total_loss: 1.154  loss_cls: 0.2108  loss_box_reg: 0.1285  loss_mask: 0.5608  loss_rpn_cls: 0.02424  loss_rpn_loc: 0.1207    time: 0.7962  last_time: 0.7369  data_time: 0.0378  last_data_time: 0.0058   lr: 0.00011988  max_mem: 5617M
# [01/05 14:53:17 d2.utils.events]:  eta: 0:53:20  iter: 79  total_loss: 0.9859  loss_cls: 0.1656  loss_box_reg: 0.127  loss_mask: 0.4801  loss_rpn_cls: 0.03397  loss_rpn_loc: 0.1455    time: 0.8012  last_time: 1.2402  data_time: 0.0152  last_data_time: 0.0135   lr: 0.00015984  max_mem: 5617M
# [01/05 14:53:34 d2.utils.events]:  eta: 0:53:58  iter: 99  total_loss: 0.9258  loss_cls: 0.1398  loss_box_reg: 0.1201  loss_mask: 0.4796  loss_rpn_cls: 0.02762  loss_rpn_loc: 0.1284    time: 0.8137  last_time: 1.1601  data_time: 0.0149  last_data_time: 0.0395   lr: 0.0001998  max_mem: 5617M
# [01/05 14:53:53 d2.utils.events]:  eta: 0:54:08  iter: 119  total_loss: 0.9251  loss_cls: 0.1432  loss_box_reg: 0.1306  loss_mask: 0.4136  loss_rpn_cls: 0.0412  loss_rpn_loc: 0.1505    time: 0.8338  last_time: 0.9489  data_time: 0.0929  last_data_time: 0.0056   lr: 0.00023976  max_mem: 5617M
# [01/05 14:54:09 d2.utils.events]:  eta: 0:53:48  iter: 139  total_loss: 0.7958  loss_cls: 0.1247  loss_box_reg: 0.1265  loss_mask: 0.3274  loss_rpn_cls: 0.02512  loss_rpn_loc: 0.1142    time: 0.8328  last_time: 0.9169  data_time: 0.0302  last_data_time: 0.0106   lr: 0.00027972  max_mem: 5617M
# [01/05 14:54:28 d2.utils.events]:  eta: 0:53:37  iter: 159  total_loss: 0.7759  loss_cls: 0.1125  loss_box_reg: 0.1189  loss_mask: 0.3272  loss_rpn_cls: 0.02702  loss_rpn_loc: 0.1477    time: 0.8448  last_time: 0.9219  data_time: 0.0094  last_data_time: 0.0078   lr: 0.00031968  max_mem: 5620M
# [01/05 14:54:46 d2.utils.events]:  eta: 0:53:35  iter: 179  total_loss: 0.7518  loss_cls: 0.1168  loss_box_reg: 0.1369  loss_mask: 0.3214  loss_rpn_cls: 0.03054  loss_rpn_loc: 0.1087    time: 0.8504  last_time: 1.2383  data_time: 0.0308  last_data_time: 0.0316   lr: 0.00035964  max_mem: 5620M
# [01/05 14:55:03 d2.utils.events]:  eta: 0:53:37  iter: 199  total_loss: 0.6794  loss_cls: 0.1038  loss_box_reg: 0.1359  loss_mask: 0.2798  loss_rpn_cls: 0.02347  loss_rpn_loc: 0.1041    time: 0.8540  last_time: 0.7595  data_time: 0.0327  last_data_time: 0.0213   lr: 0.0003996  max_mem: 5740M
# [01/05 14:55:21 d2.utils.events]:  eta: 0:53:21  iter: 219  total_loss: 0.5765  loss_cls: 0.08416  loss_box_reg: 0.1258  loss_mask: 0.1824  loss_rpn_cls: 0.01614  loss_rpn_loc: 0.1093    time: 0.8546  last_time: 0.7364  data_time: 0.0219  last_data_time: 0.0070   lr: 0.00043956  max_mem: 5740M
# [01/05 14:55:38 d2.utils.events]:  eta: 0:53:01  iter: 239  total_loss: 0.5695  loss_cls: 0.08661  loss_box_reg: 0.1342  loss_mask: 0.2393  loss_rpn_cls: 0.01163  loss_rpn_loc: 0.09384    time: 0.8543  last_time: 1.0703  data_time: 0.0094  last_data_time: 0.0061   lr: 0.00047952  max_mem: 5740M
# [01/05 14:55:55 d2.utils.events]:  eta: 0:52:49  iter: 259  total_loss: 0.5217  loss_cls: 0.07352  loss_box_reg: 0.1163  loss_mask: 0.1894  loss_rpn_cls: 0.01376  loss_rpn_loc: 0.1384    time: 0.8541  last_time: 0.6487  data_time: 0.0130  last_data_time: 0.0070   lr: 0.00051948  max_mem: 5740M
# [01/05 14:56:12 d2.utils.events]:  eta: 0:52:46  iter: 279  total_loss: 0.6258  loss_cls: 0.09067  loss_box_reg: 0.137  loss_mask: 0.2123  loss_rpn_cls: 0.02257  loss_rpn_loc: 0.1142    time: 0.8546  last_time: 0.5752  data_time: 0.0097  last_data_time: 0.0083   lr: 0.00055944  max_mem: 5740M
# [01/05 14:56:31 d2.utils.events]:  eta: 0:52:33  iter: 299  total_loss: 0.5811  loss_cls: 0.0708  loss_box_reg: 0.1106  loss_mask: 0.17  loss_rpn_cls: 0.01179  loss_rpn_loc: 0.1963    time: 0.8608  last_time: 1.1809  data_time: 0.0198  last_data_time: 0.0112   lr: 0.0005994  max_mem: 5740M
# [01/05 14:56:49 d2.utils.events]:  eta: 0:52:32  iter: 319  total_loss: 0.5126  loss_cls: 0.06567  loss_box_reg: 0.1157  loss_mask: 0.1779  loss_rpn_cls: 0.01186  loss_rpn_loc: 0.1439    time: 0.8649  last_time: 0.8375  data_time: 0.0155  last_data_time: 0.0233   lr: 0.00063936  max_mem: 5740M
# [01/05 14:57:06 d2.utils.events]:  eta: 0:52:25  iter: 339  total_loss: 0.5225  loss_cls: 0.0625  loss_box_reg: 0.1107  loss_mask: 0.1793  loss_rpn_cls: 0.009217  loss_rpn_loc: 0.1172    time: 0.8641  last_time: 0.9746  data_time: 0.0101  last_data_time: 0.0171   lr: 0.00067932  max_mem: 5740M
# [01/05 14:57:24 d2.utils.events]:  eta: 0:52:13  iter: 359  total_loss: 0.4866  loss_cls: 0.07086  loss_box_reg: 0.09906  loss_mask: 0.1834  loss_rpn_cls: 0.01575  loss_rpn_loc: 0.1169    time: 0.8651  last_time: 0.8408  data_time: 0.0142  last_data_time: 0.0074   lr: 0.00071928  max_mem: 5740M
# [01/05 14:57:40 d2.utils.events]:  eta: 0:51:56  iter: 379  total_loss: 0.4451  loss_cls: 0.05037  loss_box_reg: 0.08505  loss_mask: 0.1899  loss_rpn_cls: 0.01133  loss_rpn_loc: 0.08633    time: 0.8611  last_time: 0.6583  data_time: 0.0127  last_data_time: 0.0072   lr: 0.00075924  max_mem: 5740M
# [01/05 14:57:58 d2.utils.events]:  eta: 0:51:41  iter: 399  total_loss: 0.4973  loss_cls: 0.04727  loss_box_reg: 0.08973  loss_mask: 0.1419  loss_rpn_cls: 0.01364  loss_rpn_loc: 0.15    time: 0.8637  last_time: 1.3395  data_time: 0.0351  last_data_time: 0.0016   lr: 0.0007992  max_mem: 5740M
# [01/05 14:58:15 d2.utils.events]:  eta: 0:51:33  iter: 419  total_loss: 0.4437  loss_cls: 0.06039  loss_box_reg: 0.08411  loss_mask: 0.1866  loss_rpn_cls: 0.007103  loss_rpn_loc: 0.09266    time: 0.8625  last_time: 0.6822  data_time: 0.0111  last_data_time: 0.0106   lr: 0.00083916  max_mem: 5740M
# [01/05 14:58:32 d2.utils.events]:  eta: 0:51:21  iter: 439  total_loss: 0.4678  loss_cls: 0.05477  loss_box_reg: 0.07002  loss_mask: 0.156  loss_rpn_cls: 0.01239  loss_rpn_loc: 0.1494    time: 0.8620  last_time: 0.8285  data_time: 0.0132  last_data_time: 0.0054   lr: 0.00087912  max_mem: 5740M
# [01/05 14:58:49 d2.utils.events]:  eta: 0:51:05  iter: 459  total_loss: 0.437  loss_cls: 0.03398  loss_box_reg: 0.07462  loss_mask: 0.124  loss_rpn_cls: 0.01048  loss_rpn_loc: 0.153    time: 0.8616  last_time: 1.2044  data_time: 0.0122  last_data_time: 0.0052   lr: 0.00091908  max_mem: 5740M
# [01/05 14:59:06 d2.utils.events]:  eta: 0:50:58  iter: 479  total_loss: 0.4395  loss_cls: 0.04351  loss_box_reg: 0.07824  loss_mask: 0.1569  loss_rpn_cls: 0.01038  loss_rpn_loc: 0.1155    time: 0.8620  last_time: 0.8625  data_time: 0.0187  last_data_time: 0.0020   lr: 0.00095904  max_mem: 5740M
# [01/05 14:59:26 d2.utils.events]:  eta: 0:50:50  iter: 499  total_loss: 0.4716  loss_cls: 0.05433  loss_box_reg: 0.07339  loss_mask: 0.1784  loss_rpn_cls: 0.00949  loss_rpn_loc: 0.146    time: 0.8662  last_time: 0.9477  data_time: 0.0303  last_data_time: 0.0184   lr: 0.000999  max_mem: 5740M
# [01/05 14:59:44 d2.utils.events]:  eta: 0:50:34  iter: 519  total_loss: 0.4552  loss_cls: 0.03624  loss_box_reg: 0.05979  loss_mask: 0.2086  loss_rpn_cls: 0.01428  loss_rpn_loc: 0.1378    time: 0.8675  last_time: 0.8108  data_time: 0.0089  last_data_time: 0.0086   lr: 0.001039  max_mem: 5740M
# [01/05 15:00:02 d2.utils.events]:  eta: 0:50:17  iter: 539  total_loss: 0.4225  loss_cls: 0.05141  loss_box_reg: 0.06611  loss_mask: 0.1476  loss_rpn_cls: 0.006215  loss_rpn_loc: 0.1506    time: 0.8683  last_time: 0.8205  data_time: 0.0131  last_data_time: 0.0207   lr: 0.0010789  max_mem: 5741M
# [01/05 15:00:19 d2.utils.events]:  eta: 0:50:03  iter: 559  total_loss: 0.4878  loss_cls: 0.04444  loss_box_reg: 0.0561  loss_mask: 0.1537  loss_rpn_cls: 0.01741  loss_rpn_loc: 0.1584    time: 0.8691  last_time: 0.8633  data_time: 0.0120  last_data_time: 0.0042   lr: 0.0011189  max_mem: 5741M
# [01/05 15:00:37 d2.utils.events]:  eta: 0:49:47  iter: 579  total_loss: 0.4442  loss_cls: 0.04581  loss_box_reg: 0.05478  loss_mask: 0.1576  loss_rpn_cls: 0.01353  loss_rpn_loc: 0.1304    time: 0.8686  last_time: 0.7477  data_time: 0.0125  last_data_time: 0.0295   lr: 0.0011588  max_mem: 5741M
# [01/05 15:00:54 d2.utils.events]:  eta: 0:49:36  iter: 599  total_loss: 0.3978  loss_cls: 0.04528  loss_box_reg: 0.0606  loss_mask: 0.1791  loss_rpn_cls: 0.01055  loss_rpn_loc: 0.09929    time: 0.8681  last_time: 0.6733  data_time: 0.0105  last_data_time: 0.0186   lr: 0.0011988  max_mem: 5741M
# [01/05 15:01:10 d2.utils.events]:  eta: 0:49:24  iter: 619  total_loss: 0.4005  loss_cls: 0.0345  loss_box_reg: 0.06682  loss_mask: 0.1227  loss_rpn_cls: 0.007607  loss_rpn_loc: 0.1568    time: 0.8669  last_time: 0.9224  data_time: 0.0112  last_data_time: 0.0156   lr: 0.0012388  max_mem: 5741M
# [01/05 15:01:27 d2.utils.events]:  eta: 0:49:09  iter: 639  total_loss: 0.3757  loss_cls: 0.04181  loss_box_reg: 0.06347  loss_mask: 0.1502  loss_rpn_cls: 0.00877  loss_rpn_loc: 0.1342    time: 0.8667  last_time: 0.8083  data_time: 0.0137  last_data_time: 0.0064   lr: 0.0012787  max_mem: 5741M
# [01/05 15:01:47 d2.utils.events]:  eta: 0:48:57  iter: 659  total_loss: 0.4142  loss_cls: 0.04178  loss_box_reg: 0.05892  loss_mask: 0.178  loss_rpn_cls: 0.01336  loss_rpn_loc: 0.08297    time: 0.8698  last_time: 1.3573  data_time: 0.0129  last_data_time: 0.0202   lr: 0.0013187  max_mem: 5741M
# [01/05 15:02:03 d2.utils.events]:  eta: 0:48:38  iter: 679  total_loss: 0.4488  loss_cls: 0.04288  loss_box_reg: 0.06706  loss_mask: 0.1975  loss_rpn_cls: 0.01494  loss_rpn_loc: 0.07972    time: 0.8686  last_time: 0.8710  data_time: 0.0233  last_data_time: 0.0096   lr: 0.0013586  max_mem: 5741M
# [01/05 15:02:22 d2.utils.events]:  eta: 0:48:27  iter: 699  total_loss: 0.3719  loss_cls: 0.02938  loss_box_reg: 0.04994  loss_mask: 0.1063  loss_rpn_cls: 0.01183  loss_rpn_loc: 0.1402    time: 0.8695  last_time: 0.7435  data_time: 0.0119  last_data_time: 0.0094   lr: 0.0013986  max_mem: 5741M
# [01/05 15:02:40 d2.utils.events]:  eta: 0:48:19  iter: 719  total_loss: 0.4236  loss_cls: 0.04155  loss_box_reg: 0.05844  loss_mask: 0.1577  loss_rpn_cls: 0.006488  loss_rpn_loc: 0.1249    time: 0.8714  last_time: 0.6917  data_time: 0.0117  last_data_time: 0.0073   lr: 0.0014386  max_mem: 5741M
# [01/05 15:02:59 d2.utils.events]:  eta: 0:48:04  iter: 739  total_loss: 0.3722  loss_cls: 0.03606  loss_box_reg: 0.0585  loss_mask: 0.1372  loss_rpn_cls: 0.009214  loss_rpn_loc: 0.1114    time: 0.8732  last_time: 0.7257  data_time: 0.0170  last_data_time: 0.0068   lr: 0.0014785  max_mem: 5741M
# [01/05 15:03:18 d2.utils.events]:  eta: 0:47:52  iter: 759  total_loss: 0.3864  loss_cls: 0.03562  loss_box_reg: 0.05971  loss_mask: 0.1587  loss_rpn_cls: 0.008543  loss_rpn_loc: 0.113    time: 0.8755  last_time: 0.7896  data_time: 0.0095  last_data_time: 0.0149   lr: 0.0015185  max_mem: 5741M
# [01/05 15:03:37 d2.utils.events]:  eta: 0:47:38  iter: 779  total_loss: 0.3895  loss_cls: 0.04386  loss_box_reg: 0.05827  loss_mask: 0.1479  loss_rpn_cls: 0.008884  loss_rpn_loc: 0.1092    time: 0.8772  last_time: 1.0980  data_time: 0.0110  last_data_time: 0.0043   lr: 0.0015584  max_mem: 5741M
# [01/05 15:03:55 d2.utils.events]:  eta: 0:47:27  iter: 799  total_loss: 0.4031  loss_cls: 0.0371  loss_box_reg: 0.06714  loss_mask: 0.1542  loss_rpn_cls: 0.007148  loss_rpn_loc: 0.1531    time: 0.8778  last_time: 1.4314  data_time: 0.0139  last_data_time: 0.0025   lr: 0.0015984  max_mem: 5741M
# [01/05 15:04:13 d2.utils.events]:  eta: 0:47:10  iter: 819  total_loss: 0.4613  loss_cls: 0.03679  loss_box_reg: 0.06533  loss_mask: 0.1332  loss_rpn_cls: 0.005576  loss_rpn_loc: 0.1021    time: 0.8778  last_time: 0.6651  data_time: 0.0114  last_data_time: 0.0071   lr: 0.0016384  max_mem: 5741M
# [01/05 15:04:32 d2.utils.events]:  eta: 0:46:56  iter: 839  total_loss: 0.4223  loss_cls: 0.03821  loss_box_reg: 0.04615  loss_mask: 0.1404  loss_rpn_cls: 0.009454  loss_rpn_loc: 0.1493    time: 0.8795  last_time: 0.8386  data_time: 0.0113  last_data_time: 0.0039   lr: 0.0016783  max_mem: 5741M
# [01/05 15:04:48 d2.utils.events]:  eta: 0:46:39  iter: 859  total_loss: 0.3823  loss_cls: 0.03147  loss_box_reg: 0.05059  loss_mask: 0.1307  loss_rpn_cls: 0.006051  loss_rpn_loc: 0.1253    time: 0.8781  last_time: 0.6812  data_time: 0.0121  last_data_time: 0.0147   lr: 0.0017183  max_mem: 5741M
# [01/05 15:05:06 d2.utils.events]:  eta: 0:46:22  iter: 879  total_loss: 0.3868  loss_cls: 0.03194  loss_box_reg: 0.04827  loss_mask: 0.1271  loss_rpn_cls: 0.005439  loss_rpn_loc: 0.1465    time: 0.8786  last_time: 0.8603  data_time: 0.0123  last_data_time: 0.0136   lr: 0.0017582  max_mem: 5741M
# [01/05 15:05:25 d2.utils.events]:  eta: 0:46:06  iter: 899  total_loss: 0.4085  loss_cls: 0.03293  loss_box_reg: 0.0511  loss_mask: 0.1426  loss_rpn_cls: 0.008403  loss_rpn_loc: 0.1459    time: 0.8795  last_time: 1.0478  data_time: 0.0108  last_data_time: 0.0027   lr: 0.0017982  max_mem: 5741M
# [01/05 15:05:43 d2.utils.events]:  eta: 0:45:50  iter: 919  total_loss: 0.3565  loss_cls: 0.03035  loss_box_reg: 0.04516  loss_mask: 0.1347  loss_rpn_cls: 0.007202  loss_rpn_loc: 0.1318    time: 0.8801  last_time: 1.0962  data_time: 0.0128  last_data_time: 0.0035   lr: 0.0018382  max_mem: 5741M
# [01/05 15:06:00 d2.utils.events]:  eta: 0:45:35  iter: 939  total_loss: 0.3976  loss_cls: 0.03566  loss_box_reg: 0.05645  loss_mask: 0.1382  loss_rpn_cls: 0.009721  loss_rpn_loc: 0.1263    time: 0.8797  last_time: 0.8731  data_time: 0.0138  last_data_time: 0.0264   lr: 0.0018781  max_mem: 5741M
# [01/05 15:06:17 d2.utils.events]:  eta: 0:45:15  iter: 959  total_loss: 0.365  loss_cls: 0.0332  loss_box_reg: 0.05215  loss_mask: 0.1436  loss_rpn_cls: 0.007349  loss_rpn_loc: 0.1228    time: 0.8791  last_time: 1.0586  data_time: 0.0076  last_data_time: 0.0060   lr: 0.0019181  max_mem: 5741M
# [01/05 15:06:34 d2.utils.events]:  eta: 0:44:59  iter: 979  total_loss: 0.3661  loss_cls: 0.03359  loss_box_reg: 0.06011  loss_mask: 0.1594  loss_rpn_cls: 0.01092  loss_rpn_loc: 0.1127    time: 0.8789  last_time: 1.1256  data_time: 0.0122  last_data_time: 0.0202   lr: 0.001958  max_mem: 5741M
# [01/05 15:06:52 d2.utils.events]:  eta: 0:44:47  iter: 999  total_loss: 0.3956  loss_cls: 0.0384  loss_box_reg: 0.05689  loss_mask: 0.1453  loss_rpn_cls: 0.008628  loss_rpn_loc: 0.1184    time: 0.8793  last_time: 0.9762  data_time: 0.0272  last_data_time: 0.0352   lr: 0.001998  max_mem: 5741M
# [01/05 15:07:09 d2.utils.events]:  eta: 0:44:30  iter: 1019  total_loss: 0.3577  loss_cls: 0.03617  loss_box_reg: 0.05788  loss_mask: 0.1254  loss_rpn_cls: 0.00562  loss_rpn_loc: 0.1018    time: 0.8780  last_time: 0.6683  data_time: 0.0119  last_data_time: 0.0171   lr: 0.002  max_mem: 5741M
# [01/05 15:07:28 d2.utils.events]:  eta: 0:44:20  iter: 1039  total_loss: 0.3201  loss_cls: 0.02706  loss_box_reg: 0.05222  loss_mask: 0.08901  loss_rpn_cls: 0.006006  loss_rpn_loc: 0.1221    time: 0.8797  last_time: 0.7999  data_time: 0.0103  last_data_time: 0.0353   lr: 0.002  max_mem: 5741M
# [01/05 15:07:46 d2.utils.events]:  eta: 0:44:06  iter: 1059  total_loss: 0.4107  loss_cls: 0.04085  loss_box_reg: 0.06337  loss_mask: 0.1577  loss_rpn_cls: 0.005464  loss_rpn_loc: 0.09743    time: 0.8802  last_time: 0.9354  data_time: 0.0161  last_data_time: 0.0102   lr: 0.002  max_mem: 5741M
# [01/05 15:08:03 d2.utils.events]:  eta: 0:43:54  iter: 1079  total_loss: 0.3699  loss_cls: 0.03459  loss_box_reg: 0.06675  loss_mask: 0.1545  loss_rpn_cls: 0.008792  loss_rpn_loc: 0.07381    time: 0.8794  last_time: 0.9421  data_time: 0.0201  last_data_time: 0.0091   lr: 0.002  max_mem: 5741M
# ...
# [01/05 15:35:11 d2.utils.events]:  eta: 0:18:37  iter: 2899  total_loss: 0.2952  loss_cls: 0.02785  loss_box_reg: 0.05052  loss_mask: 0.1225  loss_rpn_cls: 0.005853  loss_rpn_loc: 0.08446    time: 0.8886  last_time: 1.1578  data_time: 0.0100  last_data_time: 0.0040   lr: 0.002  max_mem: 5743M
# [01/05 15:35:30 d2.utils.events]:  eta: 0:18:20  iter: 2919  total_loss: 0.2663  loss_cls: 0.02603  loss_box_reg: 0.04838  loss_mask: 0.1207  loss_rpn_cls: 0.005518  loss_rpn_loc: 0.09263    time: 0.8888  last_time: 1.1580  data_time: 0.0117  last_data_time: 0.0087   lr: 0.002  max_mem: 5743M
# [01/05 15:35:48 d2.utils.events]:  eta: 0:18:03  iter: 2939  total_loss: 0.2806  loss_cls: 0.01901  loss_box_reg: 0.04953  loss_mask: 0.1042  loss_rpn_cls: 0.007436  loss_rpn_loc: 0.07567    time: 0.8889  last_time: 0.8453  data_time: 0.0117  last_data_time: 0.0068   lr: 0.002  max_mem: 5743M
# [01/05 15:36:06 d2.utils.events]:  eta: 0:17:46  iter: 2959  total_loss: 0.2897  loss_cls: 0.03026  loss_box_reg: 0.05472  loss_mask: 0.122  loss_rpn_cls: 0.004021  loss_rpn_loc: 0.0576    time: 0.8891  last_time: 0.9308  data_time: 0.0264  last_data_time: 0.0059   lr: 0.002  max_mem: 5743M
# [01/05 15:36:24 d2.utils.events]:  eta: 0:17:28  iter: 2979  total_loss: 0.275  loss_cls: 0.03201  loss_box_reg: 0.05141  loss_mask: 0.1059  loss_rpn_cls: 0.003159  loss_rpn_loc: 0.09443    time: 0.8891  last_time: 1.0487  data_time: 0.0118  last_data_time: 0.0049   lr: 0.002  max_mem: 5743M
# [01/05 15:36:42 d2.utils.events]:  eta: 0:17:11  iter: 2999  total_loss: 0.2631  loss_cls: 0.01995  loss_box_reg: 0.03724  loss_mask: 0.09745  loss_rpn_cls: 0.004155  loss_rpn_loc: 0.09299    time: 0.8890  last_time: 0.7849  data_time: 0.0136  last_data_time: 0.0164   lr: 0.002  max_mem: 5743M
# [01/05 15:37:00 d2.utils.events]:  eta: 0:16:52  iter: 3019  total_loss: 0.2538  loss_cls: 0.01867  loss_box_reg: 0.04265  loss_mask: 0.1162  loss_rpn_cls: 0.004132  loss_rpn_loc: 0.07124    time: 0.8891  last_time: 0.8474  data_time: 0.0158  last_data_time: 0.0048   lr: 0.002  max_mem: 5743M
# [01/05 15:37:19 d2.utils.events]:  eta: 0:16:36  iter: 3039  total_loss: 0.2973  loss_cls: 0.02403  loss_box_reg: 0.04702  loss_mask: 0.09777  loss_rpn_cls: 0.005633  loss_rpn_loc: 0.09499    time: 0.8896  last_time: 0.8728  data_time: 0.0109  last_data_time: 0.0090   lr: 0.002  max_mem: 5743M
# [01/05 15:37:36 d2.utils.events]:  eta: 0:16:18  iter: 3059  total_loss: 0.2886  loss_cls: 0.02219  loss_box_reg: 0.0503  loss_mask: 0.1277  loss_rpn_cls: 0.004249  loss_rpn_loc: 0.06545    time: 0.8893  last_time: 0.9468  data_time: 0.0289  last_data_time: 0.0456   lr: 0.002  max_mem: 5743M
# [01/05 15:37:54 d2.utils.events]:  eta: 0:16:01  iter: 3079  total_loss: 0.283  loss_cls: 0.02509  loss_box_reg: 0.05326  loss_mask: 0.1133  loss_rpn_cls: 0.003001  loss_rpn_loc: 0.06893    time: 0.8894  last_time: 1.2197  data_time: 0.0299  last_data_time: 0.0237   lr: 0.002  max_mem: 5743M
# [01/05 15:38:12 d2.utils.events]:  eta: 0:15:43  iter: 3099  total_loss: 0.2517  loss_cls: 0.01945  loss_box_reg: 0.04231  loss_mask: 0.1031  loss_rpn_cls: 0.002799  loss_rpn_loc: 0.09324    time: 0.8896  last_time: 1.4348  data_time: 0.0118  last_data_time: 0.0063   lr: 0.002  max_mem: 5743M
# [01/05 15:38:31 d2.utils.events]:  eta: 0:15:26  iter: 3119  total_loss: 0.3188  loss_cls: 0.02455  loss_box_reg: 0.05157  loss_mask: 0.1003  loss_rpn_cls: 0.005266  loss_rpn_loc: 0.09523    time: 0.8899  last_time: 0.9013  data_time: 0.0136  last_data_time: 0.0044   lr: 0.002  max_mem: 5743M
# [01/05 15:38:49 d2.utils.events]:  eta: 0:15:10  iter: 3139  total_loss: 0.2915  loss_cls: 0.02346  loss_box_reg: 0.04856  loss_mask: 0.1013  loss_rpn_cls: 0.003137  loss_rpn_loc: 0.09042    time: 0.8899  last_time: 0.9590  data_time: 0.0107  last_data_time: 0.0099   lr: 0.002  max_mem: 5743M
# [01/05 15:39:07 d2.utils.events]:  eta: 0:14:51  iter: 3159  total_loss: 0.2608  loss_cls: 0.02361  loss_box_reg: 0.04387  loss_mask: 0.112  loss_rpn_cls: 0.004683  loss_rpn_loc: 0.06546    time: 0.8899  last_time: 0.7002  data_time: 0.0131  last_data_time: 0.0104   lr: 0.002  max_mem: 5743M
# [01/05 15:39:24 d2.utils.events]:  eta: 0:14:34  iter: 3179  total_loss: 0.2854  loss_cls: 0.01919  loss_box_reg: 0.04004  loss_mask: 0.1159  loss_rpn_cls: 0.002771  loss_rpn_loc: 0.07919    time: 0.8897  last_time: 0.9157  data_time: 0.0111  last_data_time: 0.0146   lr: 0.002  max_mem: 5743M
# [01/05 15:39:42 d2.utils.events]:  eta: 0:14:16  iter: 3199  total_loss: 0.2543  loss_cls: 0.01749  loss_box_reg: 0.03226  loss_mask: 0.09027  loss_rpn_cls: 0.004955  loss_rpn_loc: 0.1076    time: 0.8897  last_time: 0.9745  data_time: 0.0153  last_data_time: 0.1231   lr: 0.002  max_mem: 5743M
# [01/05 15:40:00 d2.utils.events]:  eta: 0:13:59  iter: 3219  total_loss: 0.2748  loss_cls: 0.02558  loss_box_reg: 0.04601  loss_mask: 0.124  loss_rpn_cls: 0.003131  loss_rpn_loc: 0.09485    time: 0.8898  last_time: 1.2025  data_time: 0.0112  last_data_time: 0.0192   lr: 0.002  max_mem: 5743M
# [01/05 15:40:18 d2.utils.events]:  eta: 0:13:42  iter: 3239  total_loss: 0.242  loss_cls: 0.02778  loss_box_reg: 0.04285  loss_mask: 0.1108  loss_rpn_cls: 0.004403  loss_rpn_loc: 0.06316    time: 0.8900  last_time: 0.6691  data_time: 0.0144  last_data_time: 0.0109   lr: 0.002  max_mem: 5743M
# [01/05 15:40:35 d2.utils.events]:  eta: 0:13:23  iter: 3259  total_loss: 0.2592  loss_cls: 0.02474  loss_box_reg: 0.05075  loss_mask: 0.1031  loss_rpn_cls: 0.003123  loss_rpn_loc: 0.06916    time: 0.8896  last_time: 0.8602  data_time: 0.0096  last_data_time: 0.0076   lr: 0.002  max_mem: 5743M
# [01/05 15:40:54 d2.utils.events]:  eta: 0:13:06  iter: 3279  total_loss: 0.2801  loss_cls: 0.02559  loss_box_reg: 0.04717  loss_mask: 0.101  loss_rpn_cls: 0.005897  loss_rpn_loc: 0.08627    time: 0.8899  last_time: 0.8585  data_time: 0.0342  last_data_time: 0.0083   lr: 0.002  max_mem: 5743M
# [01/05 15:41:11 d2.utils.events]:  eta: 0:12:49  iter: 3299  total_loss: 0.3351  loss_cls: 0.02234  loss_box_reg: 0.05607  loss_mask: 0.1183  loss_rpn_cls: 0.006931  loss_rpn_loc: 0.06972    time: 0.8897  last_time: 0.7287  data_time: 0.0135  last_data_time: 0.0076   lr: 0.002  max_mem: 5743M
# [01/05 15:41:29 d2.utils.events]:  eta: 0:12:33  iter: 3319  total_loss: 0.2956  loss_cls: 0.02018  loss_box_reg: 0.04074  loss_mask: 0.1096  loss_rpn_cls: 0.004836  loss_rpn_loc: 0.07439    time: 0.8899  last_time: 0.8532  data_time: 0.0122  last_data_time: 0.0063   lr: 0.002  max_mem: 5743M
# [01/05 15:41:48 d2.utils.events]:  eta: 0:12:15  iter: 3339  total_loss: 0.285  loss_cls: 0.02201  loss_box_reg: 0.03993  loss_mask: 0.1132  loss_rpn_cls: 0.004102  loss_rpn_loc: 0.07463    time: 0.8902  last_time: 1.0929  data_time: 0.0143  last_data_time: 0.0060   lr: 0.002  max_mem: 5743M
# [01/05 15:42:05 d2.utils.events]:  eta: 0:12:00  iter: 3359  total_loss: 0.2748  loss_cls: 0.02376  loss_box_reg: 0.05082  loss_mask: 0.1235  loss_rpn_cls: 0.005054  loss_rpn_loc: 0.08526    time: 0.8901  last_time: 0.7421  data_time: 0.0111  last_data_time: 0.0041   lr: 0.002  max_mem: 5743M
# [01/05 15:42:22 d2.utils.events]:  eta: 0:11:42  iter: 3379  total_loss: 0.2835  loss_cls: 0.02105  loss_box_reg: 0.04046  loss_mask: 0.1077  loss_rpn_cls: 0.00512  loss_rpn_loc: 0.09123    time: 0.8899  last_time: 0.8018  data_time: 0.0116  last_data_time: 0.0016   lr: 0.002  max_mem: 5743M
# [01/05 15:42:40 d2.utils.events]:  eta: 0:11:25  iter: 3399  total_loss: 0.2411  loss_cls: 0.02084  loss_box_reg: 0.04414  loss_mask: 0.08898  loss_rpn_cls: 0.004799  loss_rpn_loc: 0.06975    time: 0.8898  last_time: 0.7718  data_time: 0.0137  last_data_time: 0.0099   lr: 0.002  max_mem: 5743M
# [01/05 15:42:58 d2.utils.events]:  eta: 0:11:08  iter: 3419  total_loss: 0.2796  loss_cls: 0.0241  loss_box_reg: 0.04309  loss_mask: 0.1143  loss_rpn_cls: 0.00329  loss_rpn_loc: 0.07784    time: 0.8897  last_time: 0.7360  data_time: 0.0122  last_data_time: 0.0021   lr: 0.002  max_mem: 5743M
# [01/05 15:43:16 d2.utils.events]:  eta: 0:10:51  iter: 3439  total_loss: 0.2839  loss_cls: 0.02114  loss_box_reg: 0.04476  loss_mask: 0.08605  loss_rpn_cls: 0.003878  loss_rpn_loc: 0.1024    time: 0.8899  last_time: 0.6809  data_time: 0.0089  last_data_time: 0.0063   lr: 0.002  max_mem: 5743M
# [01/05 15:43:35 d2.utils.events]:  eta: 0:10:34  iter: 3459  total_loss: 0.2637  loss_cls: 0.02376  loss_box_reg: 0.03709  loss_mask: 0.0963  loss_rpn_cls: 0.005525  loss_rpn_loc: 0.07341    time: 0.8902  last_time: 0.8454  data_time: 0.0273  last_data_time: 0.0064   lr: 0.002  max_mem: 5743M
# [01/05 15:43:52 d2.utils.events]:  eta: 0:10:16  iter: 3479  total_loss: 0.2834  loss_cls: 0.02543  loss_box_reg: 0.04301  loss_mask: 0.1052  loss_rpn_cls: 0.004072  loss_rpn_loc: 0.07305    time: 0.8900  last_time: 0.9253  data_time: 0.0161  last_data_time: 0.0122   lr: 0.002  max_mem: 5743M
# [01/05 15:44:10 d2.utils.events]:  eta: 0:09:59  iter: 3499  total_loss: 0.2722  loss_cls: 0.02824  loss_box_reg: 0.04625  loss_mask: 0.1204  loss_rpn_cls: 0.004212  loss_rpn_loc: 0.05504    time: 0.8900  last_time: 0.6767  data_time: 0.0305  last_data_time: 0.0057   lr: 0.002  max_mem: 5743M
# [01/05 15:44:27 d2.utils.events]:  eta: 0:09:42  iter: 3519  total_loss: 0.2916  loss_cls: 0.02371  loss_box_reg: 0.04894  loss_mask: 0.1234  loss_rpn_cls: 0.003995  loss_rpn_loc: 0.07581    time: 0.8900  last_time: 0.7695  data_time: 0.0264  last_data_time: 0.0065   lr: 0.002  max_mem: 5743M
# [01/05 15:44:44 d2.utils.events]:  eta: 0:09:25  iter: 3539  total_loss: 0.2872  loss_cls: 0.02697  loss_box_reg: 0.0581  loss_mask: 0.1164  loss_rpn_cls: 0.006121  loss_rpn_loc: 0.05406    time: 0.8896  last_time: 0.8728  data_time: 0.0109  last_data_time: 0.0161   lr: 0.002  max_mem: 5743M
# [01/05 15:45:01 d2.utils.events]:  eta: 0:09:07  iter: 3559  total_loss: 0.2921  loss_cls: 0.02218  loss_box_reg: 0.04692  loss_mask: 0.1173  loss_rpn_cls: 0.003674  loss_rpn_loc: 0.08327    time: 0.8895  last_time: 0.8544  data_time: 0.0112  last_data_time: 0.0048   lr: 0.002  max_mem: 5743M
# [01/05 15:45:20 d2.utils.events]:  eta: 0:08:50  iter: 3579  total_loss: 0.2629  loss_cls: 0.02273  loss_box_reg: 0.0421  loss_mask: 0.1107  loss_rpn_cls: 0.00328  loss_rpn_loc: 0.08673    time: 0.8896  last_time: 0.7062  data_time: 0.0144  last_data_time: 0.0388   lr: 0.002  max_mem: 5743M
# [01/05 15:45:37 d2.utils.events]:  eta: 0:08:33  iter: 3599  total_loss: 0.2419  loss_cls: 0.02162  loss_box_reg: 0.05144  loss_mask: 0.1091  loss_rpn_cls: 0.002813  loss_rpn_loc: 0.05831    time: 0.8895  last_time: 0.8809  data_time: 0.0154  last_data_time: 0.0322   lr: 0.002  max_mem: 5743M
# [01/05 15:45:54 d2.utils.events]:  eta: 0:08:16  iter: 3619  total_loss: 0.2646  loss_cls: 0.01984  loss_box_reg: 0.04392  loss_mask: 0.1187  loss_rpn_cls: 0.00364  loss_rpn_loc: 0.06609    time: 0.8893  last_time: 0.8231  data_time: 0.0158  last_data_time: 0.0014   lr: 0.002  max_mem: 5743M
# [01/05 15:46:13 d2.utils.events]:  eta: 0:07:59  iter: 3639  total_loss: 0.2791  loss_cls: 0.02362  loss_box_reg: 0.04438  loss_mask: 0.1132  loss_rpn_cls: 0.006087  loss_rpn_loc: 0.07681    time: 0.8895  last_time: 0.7904  data_time: 0.0119  last_data_time: 0.0083   lr: 0.002  max_mem: 5743M
# [01/05 15:46:31 d2.utils.events]:  eta: 0:07:42  iter: 3659  total_loss: 0.274  loss_cls: 0.02648  loss_box_reg: 0.05259  loss_mask: 0.1187  loss_rpn_cls: 0.004119  loss_rpn_loc: 0.0873    time: 0.8896  last_time: 0.8352  data_time: 0.0149  last_data_time: 0.0055   lr: 0.002  max_mem: 5743M
# [01/05 15:46:49 d2.utils.events]:  eta: 0:07:25  iter: 3679  total_loss: 0.2927  loss_cls: 0.02129  loss_box_reg: 0.0429  loss_mask: 0.1062  loss_rpn_cls: 0.003466  loss_rpn_loc: 0.09277    time: 0.8898  last_time: 1.0197  data_time: 0.0111  last_data_time: 0.0080   lr: 0.002  max_mem: 5743M
# [01/05 15:47:09 d2.utils.events]:  eta: 0:07:08  iter: 3699  total_loss: 0.2679  loss_cls: 0.02235  loss_box_reg: 0.04141  loss_mask: 0.1017  loss_rpn_cls: 0.003531  loss_rpn_loc: 0.09084    time: 0.8902  last_time: 0.7860  data_time: 0.0214  last_data_time: 0.0145   lr: 0.002  max_mem: 5743M
# [01/05 15:47:26 d2.utils.events]:  eta: 0:06:50  iter: 3719  total_loss: 0.267  loss_cls: 0.02365  loss_box_reg: 0.03994  loss_mask: 0.09828  loss_rpn_cls: 0.006181  loss_rpn_loc: 0.07051    time: 0.8901  last_time: 0.8541  data_time: 0.0127  last_data_time: 0.0082   lr: 0.002  max_mem: 5743M
# [01/05 15:47:43 d2.utils.events]:  eta: 0:06:33  iter: 3739  total_loss: 0.3119  loss_cls: 0.0279  loss_box_reg: 0.05475  loss_mask: 0.1167  loss_rpn_cls: 0.003926  loss_rpn_loc: 0.07459    time: 0.8899  last_time: 0.8383  data_time: 0.0109  last_data_time: 0.0058   lr: 0.002  max_mem: 5743M
# [01/05 15:48:00 d2.utils.events]:  eta: 0:06:16  iter: 3759  total_loss: 0.3186  loss_cls: 0.02762  loss_box_reg: 0.05103  loss_mask: 0.1391  loss_rpn_cls: 0.0043  loss_rpn_loc: 0.05868    time: 0.8898  last_time: 0.8305  data_time: 0.0104  last_data_time: 0.0046   lr: 0.002  max_mem: 5743M
# [01/05 15:48:20 d2.utils.events]:  eta: 0:05:59  iter: 3779  total_loss: 0.2523  loss_cls: 0.01933  loss_box_reg: 0.04119  loss_mask: 0.08291  loss_rpn_cls: 0.003514  loss_rpn_loc: 0.08176    time: 0.8901  last_time: 0.8499  data_time: 0.0201  last_data_time: 0.0113   lr: 0.002  max_mem: 5743M
# [01/05 15:48:37 d2.utils.events]:  eta: 0:05:42  iter: 3799  total_loss: 0.2853  loss_cls: 0.02388  loss_box_reg: 0.04827  loss_mask: 0.1162  loss_rpn_cls: 0.002887  loss_rpn_loc: 0.06809    time: 0.8901  last_time: 0.7080  data_time: 0.0136  last_data_time: 0.0317   lr: 0.002  max_mem: 5743M
# [01/05 15:48:55 d2.utils.events]:  eta: 0:05:25  iter: 3819  total_loss: 0.2664  loss_cls: 0.02186  loss_box_reg: 0.0453  loss_mask: 0.1122  loss_rpn_cls: 0.00389  loss_rpn_loc: 0.07296    time: 0.8901  last_time: 0.8198  data_time: 0.0132  last_data_time: 0.0497   lr: 0.002  max_mem: 5743M
# [01/05 15:49:13 d2.utils.events]:  eta: 0:05:08  iter: 3839  total_loss: 0.2542  loss_cls: 0.02333  loss_box_reg: 0.04527  loss_mask: 0.1004  loss_rpn_cls: 0.003645  loss_rpn_loc: 0.06504    time: 0.8900  last_time: 1.0061  data_time: 0.0179  last_data_time: 0.0029   lr: 0.002  max_mem: 5743M
# [01/05 15:49:30 d2.utils.events]:  eta: 0:04:50  iter: 3859  total_loss: 0.2693  loss_cls: 0.02519  loss_box_reg: 0.04917  loss_mask: 0.1231  loss_rpn_cls: 0.004441  loss_rpn_loc: 0.06811    time: 0.8899  last_time: 0.6653  data_time: 0.0105  last_data_time: 0.0139   lr: 0.002  max_mem: 5743M
# [01/05 15:49:48 d2.utils.events]:  eta: 0:04:33  iter: 3879  total_loss: 0.3283  loss_cls: 0.02343  loss_box_reg: 0.05014  loss_mask: 0.09971  loss_rpn_cls: 0.007476  loss_rpn_loc: 0.1247    time: 0.8900  last_time: 1.0682  data_time: 0.0096  last_data_time: 0.0121   lr: 0.002  max_mem: 5743M
# [01/05 15:50:06 d2.utils.events]:  eta: 0:04:16  iter: 3899  total_loss: 0.3078  loss_cls: 0.02486  loss_box_reg: 0.04452  loss_mask: 0.1279  loss_rpn_cls: 0.004251  loss_rpn_loc: 0.1174    time: 0.8900  last_time: 0.9568  data_time: 0.0095  last_data_time: 0.0063   lr: 0.002  max_mem: 5743M
# [01/05 15:50:23 d2.utils.events]:  eta: 0:03:59  iter: 3919  total_loss: 0.2648  loss_cls: 0.02718  loss_box_reg: 0.0434  loss_mask: 0.1156  loss_rpn_cls: 0.006743  loss_rpn_loc: 0.06844    time: 0.8898  last_time: 0.8635  data_time: 0.0366  last_data_time: 0.0064   lr: 0.002  max_mem: 5743M
# [01/05 15:50:41 d2.utils.events]:  eta: 0:03:42  iter: 3939  total_loss: 0.31  loss_cls: 0.03164  loss_box_reg: 0.05873  loss_mask: 0.1223  loss_rpn_cls: 0.004349  loss_rpn_loc: 0.05678    time: 0.8899  last_time: 0.8931  data_time: 0.0106  last_data_time: 0.0196   lr: 0.002  max_mem: 5743M
# [01/05 15:50:59 d2.utils.events]:  eta: 0:03:25  iter: 3959  total_loss: 0.2725  loss_cls: 0.02189  loss_box_reg: 0.0427  loss_mask: 0.09041  loss_rpn_cls: 0.005968  loss_rpn_loc: 0.07001    time: 0.8899  last_time: 0.7450  data_time: 0.0128  last_data_time: 0.0084   lr: 0.002  max_mem: 5743M

# %% [markdown]
# ### Evaluate Model

# %% [markdown]
# #### Reload Trainer

# %%
#fr5 pt 2test default aug best at 1000
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
import os

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_101_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("my_data_train",)
cfg.DATASETS.TEST = ("my_data_val",)   # no metrics implemented for this dataset
cfg.DATALOADER.NUM_WORKERS = 5

cfg.OUTPUT_DIR = "/content/drive/MyDrive/BumpsandPotholes/models/Detectron2/output/"
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")

cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.001 #0.002
cfg.SOLVER.MAX_ITER = 4200    # Number of iterations
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 512
cfg.MODEL.ROI_HEADS.NUM_CLASSES = len(classes)  # classes
cfg.TEST.EVAL_PERIOD = 4201
#cfg.MODEL.BACKBONE.FREEZE_AT = 2

trainer = MyTrainer(cfg)
#trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=True)
#trainer.train()
# Out:
# [01/05 15:57:50 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=4, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=12, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [01/05 15:57:50 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [<detectron2.data.transforms.augmentation_impl.RandomApply object at 0x7e020dd82020>, ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), <detectron2.data.transforms.augmentation_impl.RandomApply object at 0x7e020dd81de0>, RandomFlip(prob=0.2, horizontal=False, vertical=True), RandomFlip(prob=0.2)]
# WARNING [01/05 15:57:50 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [01/05 15:57:51 d2.data.datasets.coco]: Loaded 374 images in COCO format from /content/drive/MyDrive/BumpsandPotholes/models/train.json
# [01/05 15:57:51 d2.data.build]: Removed 0 images with no usable annotations. 374 images left.
# [01/05 15:57:51 d2.data.build]: Using training sampler TrainingSampler
# [01/05 15:57:51 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [01/05 15:57:51 d2.data.common]: Serializing 374 elements to byte tensors and concatenating them all ...
# [01/05 15:57:51 d2.data.common]: Serialized dataset takes 0.38 MiB
# [01/05 15:57:51 d2.data.build]: Making batched data loader with batch_size=2
# WARNING [01/05 15:57:51 d2.solver.build]: SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. These values will be ignored.
# [01/05 15:57:51 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# WARNING [01/05 15:57:51 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [01/05 15:57:51 d2.data.datasets.coco]: Loaded 94 images in COCO format from /content/drive/MyDrive/BumpsandPotholes/models/test.json
# [01/05 15:57:51 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [01/05 15:57:51 d2.data.common]: Serializing 94 elements to byte tensors and concatenating them all ...
# [01/05 15:57:51 d2.data.common]: Serialized dataset takes 0.09 MiB
# [01/05 15:57:51 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /content/drive/MyDrive/BumpsandPotholes/models/Detectron2/output/model_final.pth ...
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/fvcore/common/checkpoint.py:252: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=torch.device("cpu"))
# [01/05 15:57:51 d2.engine.hooks]: Loading scheduler from state_dict ...

# %% [markdown]
# #### Coco Evaluation

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader
evaluator = COCOEvaluator("my_data_train", cfg, False, output_dir="./output/")
val_loader = build_detection_test_loader(cfg, "my_data_train")
inference_on_dataset(trainer.model, val_loader, evaluator)
# another equivalent way is to use trainer.test
# Out:
# WARNING [01/05 15:58:27 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# WARNING [01/05 15:58:27 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [01/05 15:58:27 d2.data.datasets.coco]: Loaded 374 images in COCO format from /content/drive/MyDrive/BumpsandPotholes/models/train.json
# [01/05 15:58:27 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [01/05 15:58:27 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [01/05 15:58:27 d2.data.common]: Serializing 374 elements to byte tensors and concatenating them all ...
# [01/05 15:58:27 d2.data.common]: Serialized dataset takes 0.38 MiB
# [01/05 15:58:27 d2.evaluation.evaluator]: Start inference on 374 batches
# [01/05 15:58:30 d2.evaluation.evaluator]: Inference done 11/374. Dataloading: 0.0079 s/iter. Inference: 0.1676 s/iter. Eval: 0.0042 s/iter. Total: 0.1798 s/iter. ETA=0:01:05
# [01/05 15:58:35 d2.evaluation.evaluator]: Inference done 28/374. Dataloading: 0.0395 s/iter. Inference: 0.1682 s/iter. Eval: 0.0625 s/iter. Total: 0.2704 s/iter. ETA=0:01:33
# [01/05 15:58:40 d2.evaluation.evaluator]: Inference done 43/374. Dataloading: 0.0300 s/iter. Inference: 0.1706 s/iter. Eval: 0.0994 s/iter. Total: 0.3003 s/iter. ETA=0:01:39
# [01/05 15:58:45 d2.evaluation.evaluator]: Inference done 65/374. Dataloading: 0.0243 s/iter. Inference: 0.1665 s/iter. Eval: 0.0848 s/iter. Total: 0.2760 s/iter. ETA=0:01:25
# [01/05 15:58:50 d2.evaluation.evaluator]: Inference done 88/374. Dataloading: 0.0190 s/iter. Inference: 0.1627 s/iter. Eval: 0.0785 s/iter. Total: 0.2604 s/iter. ETA=0:01:14
# [01/05 15:58:56 d2.evaluation.evaluator]: Inference done 110/374. Dataloading: 0.0179 s/iter. Inference: 0.1622 s/iter. Eval: 0.0792 s/iter. Total: 0.2596 s/iter. ETA=0:01:08
# [01/05 15:59:02 d2.evaluation.evaluator]: Inference done 133/374. Dataloading: 0.0216 s/iter. Inference: 0.1635 s/iter. Eval: 0.0735 s/iter. Total: 0.2588 s/iter. ETA=0:01:02
# [01/05 15:59:07 d2.evaluation.evaluator]: Inference done 152/374. Dataloading: 0.0195 s/iter. Inference: 0.1629 s/iter. Eval: 0.0775 s/iter. Total: 0.2602 s/iter. ETA=0:00:57
# [01/05 15:59:13 d2.evaluation.evaluator]: Inference done 166/374. Dataloading: 0.0184 s/iter. Inference: 0.1625 s/iter. Eval: 0.0950 s/iter. Total: 0.2761 s/iter. ETA=0:00:57
# [01/05 15:59:18 d2.evaluation.evaluator]: Inference done 181/374. Dataloading: 0.0179 s/iter. Inference: 0.1672 s/iter. Eval: 0.0961 s/iter. Total: 0.2815 s/iter. ETA=0:00:54
# [01/05 15:59:23 d2.evaluation.evaluator]: Inference done 203/374. Dataloading: 0.0177 s/iter. Inference: 0.1657 s/iter. Eval: 0.0932 s/iter. Total: 0.2768 s/iter. ETA=0:00:47
# [01/05 15:59:29 d2.evaluation.evaluator]: Inference done 223/374. Dataloading: 0.0165 s/iter. Inference: 0.1650 s/iter. Eval: 0.0940 s/iter. Total: 0.2758 s/iter. ETA=0:00:41
# [01/05 15:59:35 d2.evaluation.evaluator]: Inference done 241/374. Dataloading: 0.0181 s/iter. Inference: 0.1663 s/iter. Eval: 0.0966 s/iter. Total: 0.2812 s/iter. ETA=0:00:37
# [01/05 15:59:40 d2.evaluation.evaluator]: Inference done 257/374. Dataloading: 0.0176 s/iter. Inference: 0.1672 s/iter. Eval: 0.1000 s/iter. Total: 0.2851 s/iter. ETA=0:00:33
# [01/05 15:59:45 d2.evaluation.evaluator]: Inference done 276/374. Dataloading: 0.0166 s/iter. Inference: 0.1662 s/iter. Eval: 0.1008 s/iter. Total: 0.2839 s/iter. ETA=0:00:27
# [01/05 15:59:51 d2.evaluation.evaluator]: Inference done 291/374. Dataloading: 0.0165 s/iter. Inference: 0.1658 s/iter. Eval: 0.1049 s/iter. Total: 0.2874 s/iter. ETA=0:00:23
# [01/05 15:59:56 d2.evaluation.evaluator]: Inference done 310/374. Dataloading: 0.0165 s/iter. Inference: 0.1668 s/iter. Eval: 0.1028 s/iter. Total: 0.2864 s/iter. ETA=0:00:18
# [01/05 16:00:01 d2.evaluation.evaluator]: Inference done 332/374. Dataloading: 0.0162 s/iter. Inference: 0.1663 s/iter. Eval: 0.0998 s/iter. Total: 0.2825 s/iter. ETA=0:00:11
# [01/05 16:00:06 d2.evaluation.evaluator]: Inference done 348/374. Dataloading: 0.0162 s/iter. Inference: 0.1659 s/iter. Eval: 0.1020 s/iter. Total: 0.2844 s/iter. ETA=0:00:07
# [01/05 16:00:11 d2.evaluation.evaluator]: Inference done 367/374. Dataloading: 0.0160 s/iter. Inference: 0.1661 s/iter. Eval: 0.1011 s/iter. Total: 0.2835 s/iter. ETA=0:00:01
# [01/05 16:00:13 d2.evaluation.evaluator]: Total inference time: 0:01:45.018011 (0.284602 s / iter per device, on 1 devices)
# [01/05 16:00:13 d2.evaluation.evaluator]: Total inference pure compute time: 0:01:01 (0.165867 s / iter per device, on 1 devices)
# [01/05 16:00:14 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [01/05 16:00:14 d2.evaluation.coco_evaluation]: Saving results to ./output/coco_instances_results.json
# [01/05 16:00:14 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [01/05 16:00:14 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [01/05 16:00:14 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.07 seconds.
# [01/05 16:00:14 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [01/05 16:00:14 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.822
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.952
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.670
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.730
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.847
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.859
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.861
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.732
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.772
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.883
# [01/05 16:00:14 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 82.238 | 99.541 | 95.194 | 66.951 | 73.017 | 84.696 |
# [01/05 16:00:14 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Pothole    | 73.612 | RoadPath   | 94.739 | SpeedBump  | 78.363 |
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# [01/05 16:00:14 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [01/05 16:00:14 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.21 seconds.
# [01/05 16:00:14 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [01/05 16:00:14 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.827
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.966
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.668
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.735
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.856
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.855
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.857
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.717
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.772
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.880
# [01/05 16:00:14 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 82.724 | 99.228 | 96.644 | 66.802 | 73.520 | 85.611 |
# [01/05 16:00:14 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Pothole    | 72.855 | RoadPath   | 94.797 | SpeedBump  | 80.520 |
# OrderedDict([('bbox',
#               {'AP': 82.237982035812,
#                'AP50': 99.54126937583719,
#                'AP75': 95.19361193815789,
#                'APs': 66.95142286513239,
#                'APm': 73.01712374229673,
#                'APl': 84.69576924554787,
#                'AP-Pothole': 73.61181469501894,
#                'AP-RoadPath': 94.73915749961367,
#                'AP-SpeedBump': 78.36297391280337}),
#              ('segm',
#               {'AP': 82.7240946248383,
#                'AP50': 99.22751821903914,
#                'AP75': 96.64367331262046,
#                'APs': 66.80229777437052,
#                'APm': 73.51960563939487,
#                'APl': 85.61112827001793,
#                'AP-Pothole': 72.85538936661995,
#                'AP-RoadPath': 94.79659284929399,
#                'AP-SpeedBump': 80.52030165860097})])

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader
evaluator = COCOEvaluator("my_data_val", cfg, False, output_dir="./output/")
val_loader = build_detection_test_loader(cfg, "my_data_val")
inference_on_dataset(trainer.model, val_loader, evaluator)
# another equivalent way is to use trainer.test
# Out:
# WARNING [01/05 16:00:15 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# WARNING [01/05 16:00:15 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [01/05 16:00:15 d2.data.datasets.coco]: Loaded 94 images in COCO format from /content/drive/MyDrive/BumpsandPotholes/models/test.json
# [01/05 16:00:15 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [01/05 16:00:15 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [01/05 16:00:15 d2.data.common]: Serializing 94 elements to byte tensors and concatenating them all ...
# [01/05 16:00:15 d2.data.common]: Serialized dataset takes 0.09 MiB
# [01/05 16:00:15 d2.evaluation.evaluator]: Start inference on 94 batches
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# [01/05 16:00:18 d2.evaluation.evaluator]: Inference done 11/94. Dataloading: 0.0046 s/iter. Inference: 0.1557 s/iter. Eval: 0.0440 s/iter. Total: 0.2044 s/iter. ETA=0:00:16
# [01/05 16:00:24 d2.evaluation.evaluator]: Inference done 35/94. Dataloading: 0.0048 s/iter. Inference: 0.1549 s/iter. Eval: 0.0558 s/iter. Total: 0.2157 s/iter. ETA=0:00:12
# [01/05 16:00:29 d2.evaluation.evaluator]: Inference done 49/94. Dataloading: 0.0066 s/iter. Inference: 0.1637 s/iter. Eval: 0.0913 s/iter. Total: 0.2618 s/iter. ETA=0:00:11
# [01/05 16:00:34 d2.evaluation.evaluator]: Inference done 75/94. Dataloading: 0.0055 s/iter. Inference: 0.1617 s/iter. Eval: 0.0707 s/iter. Total: 0.2381 s/iter. ETA=0:00:04
# [01/05 16:00:38 d2.evaluation.evaluator]: Total inference time: 0:00:20.958208 (0.235485 s / iter per device, on 1 devices)
# [01/05 16:00:38 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:14 (0.160122 s / iter per device, on 1 devices)
# [01/05 16:00:38 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [01/05 16:00:38 d2.evaluation.coco_evaluation]: Saving results to ./output/coco_instances_results.json
# [01/05 16:00:38 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [01/05 16:00:38 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [01/05 16:00:38 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [01/05 16:00:38 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [01/05 16:00:38 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.683
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.907
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.721
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.378
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.599
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.690
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.681
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.744
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.744
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.467
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.653
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.748
# [01/05 16:00:38 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 68.328 | 90.716 | 72.113 | 37.778 | 59.861 | 68.968 |
# [01/05 16:00:38 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Pothole    | 46.443 | RoadPath   | 90.273 | SpeedBump  | 68.269 |
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# [01/05 16:00:38 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [01/05 16:00:38 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.05 seconds.
# [01/05 16:00:38 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [01/05 16:00:38 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.707
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.924
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.799
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.328
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.610
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.727
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.684
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.753
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.753
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.651
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.765
# [01/05 16:00:38 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 70.716 | 92.431 | 79.889 | 32.778 | 61.038 | 72.715 |
# [01/05 16:00:38 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | Pothole    | 50.728 | RoadPath   | 91.005 | SpeedBump  | 70.414 |
# OrderedDict([('bbox',
#               {'AP': 68.3281572621284,
#                'AP50': 90.71621392209852,
#                'AP75': 72.11305941741216,
#                'APs': 37.77777777777777,
#                'APm': 59.860895462248834,
#                'APl': 68.968394119608,
#                'AP-Pothole': 46.44304319947948,
#                'AP-RoadPath': 90.27255566759494,
#                'AP-SpeedBump': 68.26887291931072}),
#              ('segm',
#               {'AP': 70.71573619332558,
#                'AP50': 92.43056909804294,
#                'AP75': 79.88910809474574,
#                'APs': 32.77777777777777,
#                'APm': 61.0377383976907,
#                'APl': 72.71507667512698,
#                'AP-Pothole': 50.728439104447595,
#                'AP-RoadPath': 91.00508091178908,
#                'AP-SpeedBump': 70.41368856374012})])

# %% [markdown]
# ...DONE
