# %%
# !pip install annotated-images
# Out:
# Collecting annotated-images
#   Downloading annotated_images-0.1.4.tar.gz (3.5 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: annotated-images
#   Building wheel for annotated-images (setup.py) ... done
#   Created wheel for annotated-images: filename=annotated_images-0.1.4-py3-none-any.whl size=4277 sha256=c61f1cec9f3f678be41305bc99d7154346800649825a974207a46b84deef9622
#   Stored in directory: /root/.cache/pip/wheels/f2/e3/4e/bb29b2b240a1b122d4eec3fc2c1c4e5b55ef499b7b201c6c09
# Successfully built annotated-images
# Installing collected packages: annotated-images
# Successfully installed annotated-images-0.1.4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import annotated_images

# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
annotated_images.split("/content/drive/MyDrive/BumpsandPotholes/models/dataset/", "/content/drive/MyDrive/BumpsandPotholes/models/", seed=1337, ratio=(.8, .2))
# Out:
# {'train': 374, 'test': 94, 'total': 468}

# %%
train_path = "/content/drive/MyDrive/BumpsandPotholes/models/train"

# %%
test_path = "/content/drive/MyDrive/BumpsandPotholes/models/test"

# %%
pip install labelme
# Out:
# Collecting labelme
#   Downloading labelme-5.6.0.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 46.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (from labelme) (5.2.0)
# Collecting imgviz>=1.7.5 (from labelme)
#   Downloading imgviz-1.7.6-py3-none-any.whl.metadata (6.2 kB)
# Collecting loguru (from labelme)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from labelme) (3.8.0)
# Requirement already satisfied: natsort>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from labelme) (8.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from labelme) (1.26.4)
# Collecting onnxruntime!=1.16.0,>=1.14.1 (from labelme)
#   Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting osam>=0.2.2 (from labelme)
#   Downloading osam-0.2.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: Pillow>=2.8 in /usr/local/lib/python3.10/dist-packages (from labelme) (11.0.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from labelme) (6.0.2)
# Collecting qtpy!=1.11.2 (from labelme)
#   Downloading QtPy-2.4.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from labelme) (0.25.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from labelme) (2.5.0)
# Collecting PyQt5!=5.15.3,!=5.15.4 (from labelme)
#   Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting coloredlogs (from onnxruntime!=1.16.0,>=1.14.1->labelme)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime!=1.16.0,>=1.14.1->labelme) (24.3.25)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime!=1.16.0,>=1.14.1->labelme) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime!=1.16.0,>=1.14.1->labelme) (4.25.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime!=1.16.0,>=1.14.1->labelme) (1.13.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from osam>=0.2.2->labelme) (8.1.7)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from osam>=0.2.2->labelme) (2.10.3)
# Collecting PyQt5-sip<13,>=12.15 (from PyQt5!=5.15.3,!=5.15.4->labelme)
#   Downloading PyQt5_sip-12.16.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (421 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from PyQt5!=5.15.3,!=5.15.4->labelme)
#   Downloading PyQt5_Qt5-5.15.16-py3-none-manylinux2014_x86_64.whl.metadata (536 bytes)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown->labelme) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown->labelme) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown->labelme) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown->labelme) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->labelme) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->labelme) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->labelme) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->labelme) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->labelme) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->labelme) (2.8.2)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->labelme) (1.13.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->labelme) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->labelme) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->labelme) (2024.12.12)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->labelme) (0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->labelme) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown->labelme) (2.6)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime!=1.16.0,>=1.14.1->labelme)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->osam>=0.2.2->labelme) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic->osam>=0.2.2->labelme) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic->osam>=0.2.2->labelme) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->labelme) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->labelme) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->labelme) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->labelme) (2024.12.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->labelme) (1.7.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime!=1.16.0,>=1.14.1->labelme) (1.3.0)
# Downloading imgviz-1.7.6-py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 58.5 MB/s eta 0:00:00
# Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 63.5 MB/s eta 0:00:00
# Downloading osam-0.2.2-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 57.1 MB/s eta 0:00:00
# Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 67.4 MB/s eta 0:00:00
# Downloading QtPy-2.4.2-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 7.9 MB/s eta 0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.3 MB/s eta 0:00:00
# Downloading PyQt5_Qt5-5.15.16-py3-none-manylinux2014_x86_64.whl (59.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 9.4 MB/s eta 0:00:00
# Downloading PyQt5_sip-12.16.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl (270 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.8/270.8 kB 14.3 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.3 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.7 MB/s eta 0:00:00
# Building wheels for collected packages: labelme
#   Building wheel for labelme (setup.py) ... done
#   Created wheel for labelme: filename=labelme-5.6.0-py3-none-any.whl size=1439635 sha256=db56a2d953015e4d250e2b909f1d82982315c0d485dd3ed329107cb1d3b95d0e
#   Stored in directory: /root/.cache/pip/wheels/e1/77/83/d9472090315ef4cc9cdf3efe3aa8c879200d4f7b331842f675
# Successfully built labelme
# Installing collected packages: PyQt5-Qt5, qtpy, PyQt5-sip, loguru, humanfriendly, PyQt5, coloredlogs, onnxruntime, imgviz, osam, labelme
# Successfully installed PyQt5-5.15.11 PyQt5-Qt5-5.15.16 PyQt5-sip-12.16.1 coloredlogs-15.0.1 humanfriendly-10.0 imgviz-1.7.6 labelme-5.6.0 loguru-0.7.3 onnxruntime-1.20.1 osam-0.2.2 qtpy-2.4.2

# %%
import os
import argparse
import json

from labelme import utils
import numpy as np
import glob
import PIL.Image


class labelme2coco(object):
    def __init__(self, labelme_json=[], save_json_path="./coco.json"):
        """
        :param labelme_json: the list of all labelme json file paths
        :param save_json_path: the path to save new json
        """
        self.labelme_json = labelme_json
        self.save_json_path = save_json_path
        self.images = []
        self.categories = []
        self.annotations = []
        self.label = []
        self.annID = 1
        self.height = 0
        self.width = 0

        self.save_json()

    def data_transfer(self):
        for num, json_file in enumerate(self.labelme_json):
            with open(json_file, "r") as fp:
                data = json.load(fp)
                if "imageData" in data:
                    self.images.append(self.image(data, num))
                    for shapes in data["shapes"]:
                        label = shapes["label"].split("_")
                        if label not in self.label:
                            self.label.append(label)
                        #points = shapes["points"]
                        points = [list(map(float, suba)) for suba in shapes["points"]]
                        self.annotations.append(self.annotation(points, label, num))
                        self.annID += 1

        # Sort all text labels so they are in the same order across data splits.
        self.label.sort()
        for label in self.label:
            self.categories.append(self.category(label))
        for annotation in self.annotations:
            annotation["category_id"] = self.getcatid(annotation["category_id"])

    def image(self, data, num):
        image = {}
        img = utils.img_b64_to_arr(data["imageData"])
        height, width = img.shape[:2]
        img = None
        image["height"] = height
        image["width"] = width
        image["id"] = num
        image["file_name"] = data["imagePath"].split("\\")[-1]  #windows
        print(image["file_name"])

        self.height = height
        self.width = width

        return image

    def category(self, label):
        category = {}
        category["supercategory"] = label[0]
        category["id"] = len(self.categories)
        category["name"] = label[0]
        return category

    def annotation(self, points, label, num):
        annotation = {}
        contour = np.array(points)
        x = contour[:, 0]
        y = contour[:, 1]
        area = 0.5 * np.abs(np.dot(x, np.roll(y, 1)) - np.dot(y, np.roll(x, 1)))
        annotation["segmentation"] = [list(np.asarray(points).flatten())] #[list(map(float, np.asarray(points).flatten()))] #
        annotation["iscrowd"] = 0
        annotation["area"] = area
        annotation["image_id"] = num

        annotation["bbox"] = list(map(float, self.getbbox(points)))

        annotation["category_id"] = label[0]  # self.getcatid(label)
        annotation["id"] = self.annID
        return annotation

    def getcatid(self, label):
        for category in self.categories:
            if label == category["name"]:
                return category["id"]
        print("label: {} not in categories: {}.".format(label, self.categories))
        exit()
        return -1

    def getbbox(self, points):
        polygons = points
        mask = self.polygons_to_mask([self.height, self.width], polygons)
        return self.mask2box(mask)

    def mask2box(self, mask):

        index = np.argwhere(mask == 1)
        rows = index[:, 0]
        clos = index[:, 1]

        left_top_r = np.min(rows)  # y
        left_top_c = np.min(clos)  # x

        right_bottom_r = np.max(rows)
        right_bottom_c = np.max(clos)

        return [
            left_top_c,
            left_top_r,
            right_bottom_c - left_top_c,
            right_bottom_r - left_top_r,
        ]

    def polygons_to_mask(self, img_shape, polygons):
        mask = np.zeros(img_shape, dtype=np.uint8)
        mask = PIL.Image.fromarray(mask)
        xy = list(map(tuple, polygons))
        PIL.ImageDraw.Draw(mask).polygon(xy=xy, outline=1, fill=1)
        mask = np.array(mask, dtype=bool)
        return mask

    def data2coco(self):
        data_coco = {}
        data_coco["images"] = self.images
        data_coco["categories"] = self.categories
        data_coco["annotations"] = self.annotations
        return data_coco

    def save_json(self):
        print("save coco json")
        self.data_transfer()
        self.data_coco = self.data2coco()

        print(self.save_json_path)
        os.makedirs(
            os.path.dirname(os.path.abspath(self.save_json_path)), exist_ok=True
        )
        json.dump(self.data_coco, open(self.save_json_path, "w"), indent=4)

# %% [markdown]
# # Train JSON

# %%
trainjsons = glob.glob(os.path.join(train_path, "*.json"))

# %%
train_path
# Out:
# '/content/drive/MyDrive/BumpsandPotholes/models/train'

# %%
train_path1='/content/drive/MyDrive/BumpsandPotholes/models/'

# %%
labelme2coco(trainjsons, train_path1+str("/train.json"))
# Out:
# save coco json
# RoadBumpImage130.jpg
# RoadBumpImage63.jpg
# PotholeImage54.jpg
# RoadBumpImage200.jpg
# PotholeImage155.jpg
# RoadBumpImage109.jpg
# PotholeImage129.jpg
# PotholeImage47.jpg
# PotholeImage24.jpg
# RoadBumpImage223.jpg
# RoadBumpImage227.jpg
# RoadBumpImage187.jpg
# PotholeImage85.jpg
# RoadBumpImage24.jpg
# RoadBumpImage178.jpg
# RoadBumpImage14.jpg
# PotholeImage152.jpg
# RoadBumpImage184.jpg
# PotholeImage74.jpg
# RoadBumpImage163.jpg
# PotholeImage43.jpg
# RoadBumpImage230.jpg
# PotholeImage128.jpg
# RoadBumpImage82.jpg
# PotholeImage165.jpg
# RoadBumpImage268.jpg
# PotholeImage181.jpg
# PotholeImage61.jpg
# PotholeImage70.jpg
# PotholeImage179.jpg
# RoadBumpImage158.jpg
# RoadBumpImage73.jpg
# PotholeImage142.jpg
# PotholeImage75.jpg
# RoadBumpImage13.jpg
# PotholeImage33.jpg
# RoadBumpImage153.jpg
# RoadBumpImage56.jpg
# RoadBumpImage124.jpg
# RoadBumpImage236.jpg
# PotholeImage56.jpg
# RoadBumpImage228.jpg
# PotholeImage95.jpg
# PotholeImage157.jpg
# RoadBumpImage71.jpg
# PotholeImage73.jpg
# PotholeImage159.jpg
# RoadBumpImage147.jpg
# RoadBumpImage26.jpg
# PotholeImage41.jpg
# RoadBumpImage239.jpg
# RoadBumpImage251.jpg
# PotholeImage121.jpg
# PotholeImage113.jpg
# RoadBumpImage171.jpg
# RoadBumpImage10.jpg
# RoadBumpImage263.jpg
# RoadBumpImage30.jpg
# PotholeImage5.jpg
# RoadBumpImage126.jpg
# RoadBumpImage287.jpg
# PotholeImage177.jpg
# PotholeImage69.jpg
# PotholeImage93.jpg
# PotholeImage167.jpg
# RoadBumpImage255.jpg
# RoadBumpImage229.jpg
# RoadBumpImage20.jpg
# RoadBumpImage207.jpg
# RoadBumpImage132.jpg
# PotholeImage109.jpg
# PotholeImage20.jpg
# PotholeImage160.jpg
# RoadBumpImage157.jpg
# RoadBumpImage145.jpg
# RoadBumpImage140.jpg
# RoadBumpImage33.jpg
# RoadBumpImage246.jpg
# PotholeImage112.jpg
# PotholeImage117.jpg
# PotholeImage87.jpg
# RoadBumpImage156.jpg
# RoadBumpImage50.jpg
# RoadBumpImage131.jpg
# PotholeImage26.jpg
# RoadBumpImage120.jpg
# RoadBumpImage284.jpg
# PotholeImage40.jpg
# PotholeImage175.jpg
# RoadBumpImage269.jpg
# RoadBumpImage243.jpg
# RoadBumpImage137.jpg
# RoadBumpImage278.jpg
# RoadBumpImage84.jpg
# RoadBumpImage162.jpg
# PotholeImage164.jpg
# RoadBumpImage70.jpg
# RoadBumpImage275.jpg
# RoadBumpImage254.jpg
# RoadBumpImage216.jpg
# RoadBumpImage259.jpg
# PotholeImage34.jpg
# PotholeImage132.jpg
# RoadBumpImage113.jpg
# PotholeImage99.jpg
# RoadBumpImage152.jpg
# RoadBumpImage231.jpg
# PotholeImage125.jpg
# PotholeImage173.jpg
# PotholeImage71.jpg
# RoadBumpImage138.jpg
# PotholeImage118.jpg
# RoadBumpImage219.jpg
# RoadBumpImage7.jpg
# RoadBumpImage136.jpg
# PotholeImage170.jpg
# RoadBumpImage195.jpg
# RoadBumpImage32.jpg
# PotholeImage55.jpg
# RoadBumpImage189.jpg
# RoadBumpImage142.jpg
# PotholeImage25.jpg
# PotholeImage137.jpg
# PotholeImage84.jpg
# RoadBumpImage8.jpg
# PotholeImage127.jpg
# PotholeImage161.jpg
# RoadBumpImage44.jpg
# PotholeImage6.jpg
# PotholeImage57.jpg
# RoadBumpImage93.jpg
# RoadBumpImage288.jpg
# RoadBumpImage197.jpg
# RoadBumpImage6.jpg
# RoadBumpImage34.jpg
# RoadBumpImage19.jpg
# RoadBumpImage164.jpg
# RoadBumpImage180.jpg
# PotholeImage11.jpg
# RoadBumpImage15.jpg
# RoadBumpImage208.jpg
# RoadBumpImage264.jpg
# RoadBumpImage168.jpg
# PotholeImage122.jpg
# RoadBumpImage62.jpg
# PotholeImage21.jpg
# RoadBumpImage272.jpg
# RoadBumpImage42.jpg
# RoadBumpImage183.jpg
# PotholeImage2.jpg
# RoadBumpImage221.jpg
# PotholeImage37.jpg
# RoadBumpImage85.jpg
# /content/drive/MyDrive/BumpsandPotholes/models//train.json

# %%
trainjsons
# Out:
# ['/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage130.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage63.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage54.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage200.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage155.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage109.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage129.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage47.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage24.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage223.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage227.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage187.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage85.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage24.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage178.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage14.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage152.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage184.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage74.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage163.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage43.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage230.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage128.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage82.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage165.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage268.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage181.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage61.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage70.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage179.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage158.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage73.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage142.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage75.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage13.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage33.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage153.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage56.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage124.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage236.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage56.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage228.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage95.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage157.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage71.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage73.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage159.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage147.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage26.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage41.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage239.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage251.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage121.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage113.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage171.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage10.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage263.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage30.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage5.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage126.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage287.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage177.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage69.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage93.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage167.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage255.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage229.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage20.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage207.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage132.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage109.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage20.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage160.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage157.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage145.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage18.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage289.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage62.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage122.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage155.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage134.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage64.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage11.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage39.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage165.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage114.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage162.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage148.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage262.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage27.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage181.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage163.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage54.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage198.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage182.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage139.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage176.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage169.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage67.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage214.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage48.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage49.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage143.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage86.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage129.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage59.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage37.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage29.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage212.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage19.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage67.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage77.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage77.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage98.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage52.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage150.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage100.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage78.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage66.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage16.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage211.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage143.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage64.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage171.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage49.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage235.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage292.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage133.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage79.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage58.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage175.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage238.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage145.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage144.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage167.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage291.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage160.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage3.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage81.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage35.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage39.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage9.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage110.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage17.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage111.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage128.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage176.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage61.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage22.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage179.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage215.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage2.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage204.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage136.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage51.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage97.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage59.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage185.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage3.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage126.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage110.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage63.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage105.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage79.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage1.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage105.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage23.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage72.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage41.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage273.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage253.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage91.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage159.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage114.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage89.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage115.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage118.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage22.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage283.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage270.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage92.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage23.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage96.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage18.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage38.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage94.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage158.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage76.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage256.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage241.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage169.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage265.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage194.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage16.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage244.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage147.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage190.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage249.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage149.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage173.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage36.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage80.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage101.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage257.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage161.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage83.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage222.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage177.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage141.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage266.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage183.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage226.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage98.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage286.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage174.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage146.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage170.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage94.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage31.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage282.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage174.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage45.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage4.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage74.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage203.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage101.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage108.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage88.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage153.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage111.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage58.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage138.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage146.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage121.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage141.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage103.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage86.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage108.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage281.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage154.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage51.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage87.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage96.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage89.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage206.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage5.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage21.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage46.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage134.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage135.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage102.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage17.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage53.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage68.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage210.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage38.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage172.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage149.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage279.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage90.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage102.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage36.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage188.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage123.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage78.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage50.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage154.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage144.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage81.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage112.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage72.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage116.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage166.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage119.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage271.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage166.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage65.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage280.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage97.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage10.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage90.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage140.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage117.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage48.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage66.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage168.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage199.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage234.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage247.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage8.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage42.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage103.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage68.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage25.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage191.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage276.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage140.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage33.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage246.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage112.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage117.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage87.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage156.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage50.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage131.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage26.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage120.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage284.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage40.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage175.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage269.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage243.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage137.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage278.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage84.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage162.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage164.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage70.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage275.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage254.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage216.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage259.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage34.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage132.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage113.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage99.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage152.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage231.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage125.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage173.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage71.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage138.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage118.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage219.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage7.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage136.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage170.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage195.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage32.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage55.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage189.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage142.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage25.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage137.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage84.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage8.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage127.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage161.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage44.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage6.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage57.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage93.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage288.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage197.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage6.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage34.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage19.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage164.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage180.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage11.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage15.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage208.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage264.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage168.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage122.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage62.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage21.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage272.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage42.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage183.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage2.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage221.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/PotholeImage37.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/train/RoadBumpImage85.json']

# %% [markdown]
# # Test JSON

# %%
testjsons = glob.glob(os.path.join(test_path, "*.json"))

# %%
test_path
# Out:
# '/content/drive/MyDrive/BumpsandPotholes/models/test'

# %%
test_path1='/content/drive/MyDrive/BumpsandPotholes/models/'

# %%
labelme2coco(testjsons, test_path1+str("/test.json"))
# Out:
# save coco json
# RoadBumpImage237.jpg
# RoadBumpImage274.jpg
# RoadBumpImage196.jpg
# PotholeImage120.jpg
# RoadBumpImage193.jpg
# PotholeImage44.jpg
# RoadBumpImage95.jpg
# RoadBumpImage139.jpg
# RoadBumpImage9.jpg
# RoadBumpImage220.jpg
# PotholeImage104.jpg
# RoadBumpImage53.jpg
# RoadBumpImage201.jpg
# RoadBumpImage285.jpg
# RoadBumpImage148.jpg
# RoadBumpImage293.jpg
# PotholeImage7.jpg
# PotholeImage15.jpg
# RoadBumpImage294.jpg
# PotholeImage28.jpg
# RoadBumpImage75.jpg
# PotholeImage106.jpg
# RoadBumpImage250.jpg
# PotholeImage124.jpg
# RoadBumpImage225.jpg
# RoadBumpImage240.jpg
# RoadBumpImage127.jpg
# PotholeImage133.jpg
# PotholeImage119.jpg
# RoadBumpImage91.jpg
# RoadBumpImage205.jpg
# RoadBumpImage99.jpg
# RoadBumpImage182.jpg
# RoadBumpImage233.jpg
# PotholeImage131.jpg
# RoadBumpImage192.jpg
# PotholeImage30.jpg
# RoadBumpImage47.jpg
# PotholeImage60.jpg
# RoadBumpImage217.jpg
# RoadBumpImage150.jpg
# RoadBumpImage218.jpg
# RoadBumpImage258.jpg
# RoadBumpImage252.jpg
# PotholeImage83.jpg
# RoadBumpImage43.jpg
# PotholeImage180.jpg
# PotholeImage52.jpg
# RoadBumpImage151.jpg
# PotholeImage156.jpg
# RoadBumpImage213.jpg
# RoadBumpImage100.jpg
# RoadBumpImage60.jpg
# PotholeImage107.jpg
# RoadBumpImage245.jpg
# PotholeImage82.jpg
# RoadBumpImage45.jpg
# RoadBumpImage28.jpg
# RoadBumpImage46.jpg
# RoadBumpImage69.jpg
# RoadBumpImage125.jpg
# RoadBumpImage1.jpg
# RoadBumpImage248.jpg
# RoadBumpImage261.jpg
# RoadBumpImage172.jpg
# PotholeImage130.jpg
# RoadBumpImage123.jpg
# RoadBumpImage88.jpg
# RoadBumpImage55.jpg
# RoadBumpImage135.jpg
# PotholeImage151.jpg
# RoadBumpImage106.jpg
# RoadBumpImage76.jpg
# RoadBumpImage242.jpg
# RoadBumpImage290.jpg
# PotholeImage32.jpg
# RoadBumpImage260.jpg
# RoadBumpImage12.jpg
# PotholeImage80.jpg
# RoadBumpImage104.jpg
# RoadBumpImage40.jpg
# RoadBumpImage232.jpg
# RoadBumpImage115.jpg
# PotholeImage92.jpg
# RoadBumpImage57.jpg
# RoadBumpImage31.jpg
# PotholeImage178.jpg
# RoadBumpImage277.jpg
# RoadBumpImage209.jpg
# RoadBumpImage202.jpg
# RoadBumpImage107.jpg
# RoadBumpImage267.jpg
# RoadBumpImage186.jpg
# RoadBumpImage224.jpg
# /content/drive/MyDrive/BumpsandPotholes/models//test.json

# %%
testjsons
# Out:
# ['/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage237.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage274.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage196.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage120.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage193.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage44.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage95.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage139.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage9.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage220.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage104.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage53.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage201.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage285.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage148.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage293.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage7.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage15.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage294.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage28.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage75.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage106.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage250.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage124.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage225.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage240.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage127.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage133.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage119.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage91.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage205.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage99.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage182.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage233.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage131.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage192.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage30.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage47.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage60.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage217.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage150.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage218.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage258.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage252.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage83.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage43.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage180.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage52.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage151.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage156.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage213.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage100.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage60.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage107.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage245.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage82.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage45.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage28.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage46.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage69.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage125.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage1.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage248.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage261.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage172.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage130.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage123.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage88.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage55.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage135.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage151.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage106.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage76.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage242.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage290.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage32.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage260.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage12.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage80.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage104.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage40.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage232.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage115.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage92.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage57.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage31.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/PotholeImage178.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage277.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage209.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage202.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage107.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage267.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage186.json',
#  '/content/drive/MyDrive/BumpsandPotholes/models/test/RoadBumpImage224.json']

# %% [markdown]
# ...the end of split!
